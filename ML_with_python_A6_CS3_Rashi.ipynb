# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Rameshwar Agarwal\Desktop\python\Assignment 6\FyntraCustomerData.csv")
df.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0     835 Frank Tunnel\r\nWrightmouth, MI 82180-9605            Violet
# 1   4547 Archer Common\r\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\r\nCobbborough,...            Bisque
# 3  1414 David Throughway\r\nPort Jason, OH 22070-...       SaddleBrown
# 4  14023 Rodriguez Passage\r\nPort Jacobville, PR...  MediumAquaMarine
#
#    Avg_Session_Length  Time_on_App  Time_on_Website  Length_of_Membership  \
# 0           34.497268    12.655651        39.577668              4.082621
# 1           31.926272    11.109461        37.268959              2.664034
# 2           33.000915    11.330278        37.110597              4.104543
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg_Session_Length    500 non-null    float64
#  4   Time_on_App           500 non-null    float64
#  5   Time_on_Website       500 non-null    float64
#  6   Length_of_Membership  500 non-null    float64
#  7   Yearly_Amount_Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
sns.jointplot(x='Yearly_Amount_Spent', y='Time_on_Website', data=df)

# %%
sns.jointplot(x='Yearly_Amount_Spent', y='Time_on_App', data=df)
print("This plot has strong correlation as compared to above")
# Out:
# This plot has strong correlation as compared to above

# %%
sns.pairplot(df)
print("Length of membership seems to be more correlated with Yearly aount spent")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Length of membership seems to be more correlated with Yearly aount spent

# %%
sns.lmplot(x='Length_of_Membership', y='Yearly_Amount_Spent', data= df)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg_Session_Length', 'Time_on_App',
#        'Time_on_Website', 'Length_of_Membership', 'Yearly_Amount_Spent'],
#       dtype='object')

# %%
y= df['Yearly_Amount_Spent']
X= df[['Avg_Session_Length', 'Time_on_App','Time_on_Website', 'Length_of_Membership']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X, y, test_size=0.25, random_state=80)

# %%
from sklearn.linear_model import LinearRegression

obj = LinearRegression()

obj.fit(X_train, y_train)

predictions = obj.predict(X_test)

# %%
predictions
# Out:
# array([582.94536496, 523.25664085, 427.34501874, 418.87430076,
#        569.24472824, 609.520805  , 605.71657908, 460.43193158,
#        504.90455889, 398.07074474, 575.16106847, 455.4173573 ,
#        548.09712219, 556.49000367, 523.79017193, 348.00144759,
#        684.01201524, 525.04596008, 434.76706999, 506.7263613 ,
#        411.11971161, 458.39176584, 457.116871  , 615.00767775,
#        504.9875916 , 563.26616463, 280.16039804, 534.76392501,
#        552.49333387, 535.80335437, 507.6132167 , 506.342963  ,
#        421.33255205, 372.06324028, 490.8397292 , 370.84175619,
#        457.19798544, 561.02584594, 508.20700762, 544.56297656,
#        472.9608247 , 503.62184381, 531.44534764, 508.87404871,
#        495.10868553, 638.97235144, 555.14255454, 444.71382519,
#        495.85204903, 641.75214478, 432.24501238, 572.53422188,
#        445.51122563, 481.42926956, 314.03110185, 505.47178042,
#        481.35189096, 424.54026611, 479.0669532 , 437.91346769,
# ...

# %%
plt.scatter(y_test, predictions)
