# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
hurricanes = pd.read_csv(r"C:\Users\Rameshwar Agarwal\Desktop\python\assinment 4\Hurricanes.csv")
hurricanes
# Out:
#      Year  Hurricanes
# 0    1914           0
# 1    1915           5
# 2    1916          10
# 3    1917           2
# 4    1918           4
# ..    ...         ...
# 96   2010          12
# 97   2011           7
# 98   2012          10
# 99   2013           2
# 100  2014           6
#
# [101 rows x 2 columns]

# %%
Year = np.array(hurricanes["Year"])
h = np.array(hurricanes["Hurricanes"])
plt.bar(Year, h)
plt.xlabel("Year")
plt.ylabel("No. of hurricanes")
# Out:
# Text(0, 0.5, 'No. of hurricanes')

# %%
temp= pd.read_csv(r"C:\Users\Rameshwar Agarwal\Desktop\python\assinment 4\CityTemps.csv")
temp
# Out:
#     Year  Month  Moscow  Melbourne  San Francisco
# 0   2014      1    -8.6       22.0           12.8
# 1   2014      2    -1.9       21.5           12.7
# 2   2014      3     2.8       19.5           15.0
# 3   2014      4     7.0       15.8           15.7
# 4   2014      5    16.0       13.9           17.5
# 5   2014      6    16.1       11.3           17.9
# 6   2014      7    21.1        9.9           19.4
# 7   2014      8    19.2       10.4           19.5
# 8   2014      9    12.3       12.8           20.2
# 9   2014     10     3.7       15.6           20.4
# 10  2014     11    -1.3       17.3           15.4
# 11  2014     12    -3.9       18.9           13.8
# 12  2015      1    -4.4       20.4           12.2
# 13  2015      2    -2.2       21.8           14.8
# 14  2015      3     2.0       17.4           15.7
# 15  2015      4     6.1       14.1           14.8
# 16  2015      5    14.2       12.6           14.7
# 17  2015      6    17.9        9.8           17.1
# ...

# %%
Moscow_temp = np.array(temp["Moscow"])
SanF_temp = np.array(temp["San Francisco"])

# %%
plt.hist(Moscow_temp, bins= range(-10, 25, 5), ec="black", label = "Moscow")
plt.xlabel("Temp")
plt.ylabel("Frequency")


plt.hist(SanF_temp, bins= range(10, 25, 2), ec="red", alpha = 0.7, label="San Francisco")
plt.xlabel("Temp")
plt.ylabel("Frequency")
plt.title("Temp variation over period of 2 years, 2014-2015")
plt.legend(loc = "upper right")

# %%
X = [1,2,3,4]
Y = [20, 21, 20.5, 20.8]

# %%
plt.plot(X, Y, marker = "o", mfc = "blue")

plt.axis([0, 5, 20, 21]) 

plt.xlabel("X", fontsize =20)
plt.ylabel("Y")
plt.title("X v/s Y")

error = [0.12, 0.13, 0.2, 0.1]
plt.errorbar(X,Y, yerr = error, fmt=" ")

plt.plot(figsize=(4,5))
plt.rcParams["figure.dpi"] = 100

# %%
x_string = ""
y_string = ""
for i in range(0,50):
    rand = str(np.random.randint(1, 101))
    x_string = x_string + rand+ " "
    rand = str(np.random.randint(1, 101))
    y_string = y_string + rand+ " "
x_lst = x_string.split(" ")
y_lst = y_string.split(" ")
print(x_lst, y_lst)
# Out:
# ['75', '18', '16', '99', '34', '42', '85', '17', '83', '61', '18', '20', '6', '2', '13', '66', '36', '5', '15', '45', '39', '2', '69', '80', '8', '70', '52', '62', '92', '2', '98', '5', '64', '98', '11', '63', '36', '61', '80', '78', '81', '27', '52', '56', '82', '33', '87', '83', '70', '69', ''] ['47', '74', '59', '18', '87', '18', '45', '34', '10', '1', '8', '64', '37', '73', '98', '83', '39', '64', '6', '66', '43', '3', '94', '91', '89', '68', '15', '32', '87', '32', '39', '47', '59', '46', '44', '52', '49', '18', '47', '95', '15', '25', '4', '59', '35', '95', '2', '95', '25', '90', '']

# %%
plt.scatter(x_lst, y_lst)
plt.plot(figsize=(40,40))
plt.rcParams["figure.dpi"] = 100

# %%
dict1 = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'], 
        'female': [0, 1, 1, 0, 1],'age': [42, 52, 36, 24, 73], 
        'preTestScore': [4, 24, 31, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70]}
df = pd.DataFrame(dict1)
pre_test = np.array(df["preTestScore"])
post_test = np.array(df["postTestScore"])
age = np.array(df["age"])
gender = np.array(df["female"])

# %%
plt.scatter(pre_test, post_test, s =age )

# %%
plt.scatter(pre_test, post_test, s =300, c =  gender)
