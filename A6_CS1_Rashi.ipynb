# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Rameshwar Agarwal\Desktop\python\Assignment 6\prisoners.csv")
df.head()
# Out:
#             STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 0     Andhra Pradesh  2013                                               9480
# 1  Arunachal Pradesh  2013                                                  0
# 2              Assam  2013                                                676
# 3              Bihar  2013                                               1693
# 4        Chhatisgarh  2013                                               1664
#
#    No. of Inmates benefitted by Adult Education  \
# 0                                         13758
# 1                                             0
# 2                                           750
# 3                                          3013
# 4                                          1803
#
#    No. of Inmates benefitted by Higher Education  \
# 0                                            672
# 1                                              0
# 2                                             14
# ...

# %%
df.tail()
# Out:
#         STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 30  D & N Haveli  2013                                                  0
# 31   Daman & Diu  2013                                                  0
# 32         Delhi  2013                                               1458
# 33   Lakshadweep  2013                                                  0
# 34   Pondicherry  2013                                                  0
#
#     No. of Inmates benefitted by Adult Education  \
# 30                                             0
# 31                                             0
# 32                                          1187
# 33                                             0
# 34                                             0
#
#     No. of Inmates benefitted by Higher Education  \
# 30                                              0
# 31                                              0
# 32                                            908
# ...

# %%
df.describe()
# Out:
#          YEAR  No. of Inmates benefitted by Elementary Education  \
# count    35.0                                          35.000000
# mean   2013.0                                        1057.914286
# std       0.0                                        2078.196777
# min    2013.0                                           0.000000
# 25%    2013.0                                           0.000000
# 50%    2013.0                                         167.000000
# 75%    2013.0                                        1294.500000
# max    2013.0                                        9480.000000
#
#        No. of Inmates benefitted by Adult Education  \
# count                                     35.000000
# mean                                    1534.857143
# std                                     3022.110503
# min                                        0.000000
# 25%                                        6.500000
# 50%                                      237.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 6 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   STATE/UT                                           35 non-null     object
#  1   YEAR                                               35 non-null     int64
#  2   No. of Inmates benefitted by Elementary Education  35 non-null     int64
#  3   No. of Inmates benefitted by Adult Education       35 non-null     int64
#  4   No. of Inmates benefitted by Higher Education      35 non-null     int64
#  5   No. of Inmates benefitted by Computer Course       35 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.8+ KB

# %%
df.isnull().sum()
# Out:
# STATE/UT                                             0
# YEAR                                                 0
# No. of Inmates benefitted by Elementary Education    0
# No. of Inmates benefitted by Adult Education         0
# No. of Inmates benefitted by Higher Education        0
# No. of Inmates benefitted by Computer Course         0
# dtype: int64

# %%
df[df["No. of Inmates benefitted by Elementary Education"] ==0]
# Out:
#              STATE/UT  YEAR  \
# 1   Arunachal Pradesh  2013
# 15            Manipur  2013
# 17            Mizoram  2013
# 18           Nagaland  2013
# 22             Sikkim  2013
# 29         Chandigarh  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# 33        Lakshadweep  2013
# 34        Pondicherry  2013
#
#     No. of Inmates benefitted by Elementary Education  \
# 1                                                   0
# 15                                                  0
# 17                                                  0
# 18                                                  0
# 22                                                  0
# 29                                                  0
# 30                                                  0
# 31                                                  0
# 33                                                  0
# 34                                                  0
#
# ...

# %%
df[df["No. of Inmates benefitted by Adult Education"] ==0]
# Out:
#              STATE/UT  YEAR  \
# 1   Arunachal Pradesh  2013
# 5                 Goa  2013
# 15            Manipur  2013
# 18           Nagaland  2013
# 22             Sikkim  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# 33        Lakshadweep  2013
# 34        Pondicherry  2013
#
#     No. of Inmates benefitted by Elementary Education  \
# 1                                                   0
# 5                                                   7
# 15                                                  0
# 18                                                  0
# 22                                                  0
# 30                                                  0
# 31                                                  0
# 33                                                  0
# 34                                                  0
#
#     No. of Inmates benefitted by Adult Education  \
# 1                                              0
# ...

# %%
df[df["No. of Inmates benefitted by Higher Education"]==0]
# Out:
#              STATE/UT  YEAR  \
# 1   Arunachal Pradesh  2013
# 15            Manipur  2013
# 16          Meghalaya  2013
# 18           Nagaland  2013
# 22             Sikkim  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# 33        Lakshadweep  2013
# 34        Pondicherry  2013
#
#     No. of Inmates benefitted by Elementary Education  \
# 1                                                   0
# 15                                                  0
# 16                                                  1
# 18                                                  0
# 22                                                  0
# 30                                                  0
# 31                                                  0
# 33                                                  0
# 34                                                  0
#
#     No. of Inmates benefitted by Adult Education  \
# 1                                              0
# ...

# %%
df[df["No. of Inmates benefitted by Computer Course"]==0]
# Out:
#              STATE/UT  YEAR  \
# 1   Arunachal Pradesh  2013
# 8    Himachal Pradesh  2013
# 15            Manipur  2013
# 16          Meghalaya  2013
# 17            Mizoram  2013
# 18           Nagaland  2013
# 22             Sikkim  2013
# 28      A & N Islands  2013
# 29         Chandigarh  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# 33        Lakshadweep  2013
# 34        Pondicherry  2013
#
#     No. of Inmates benefitted by Elementary Education  \
# 1                                                   0
# 8                                                  33
# 15                                                  0
# 16                                                  1
# 17                                                  0
# 18                                                  0
# 22                                                  0
# 28                                                167
# 29                                                  0
# ...

# %%
df['total_benefitted'] = df["No. of Inmates benefitted by Elementary Education"] + df["No. of Inmates benefitted by Adult Education"] + df["No. of Inmates benefitted by Higher Education"] + df["No. of Inmates benefitted by Computer Course"]
df
# Out:
#              STATE/UT  YEAR  \
# 0      Andhra Pradesh  2013
# 1   Arunachal Pradesh  2013
# 2               Assam  2013
# 3               Bihar  2013
# 4         Chhatisgarh  2013
# 5                 Goa  2013
# 6             Gujarat  2013
# 7             Haryana  2013
# 8    Himachal Pradesh  2013
# 9     Jammu & Kashmir  2013
# 10          Jharkhand  2013
# 11          Karnataka  2013
# 12             Kerala  2013
# 13     Madhya Pradesh  2013
# 14        Maharashtra  2013
# 15            Manipur  2013
# 16          Meghalaya  2013
# 17            Mizoram  2013
# 18           Nagaland  2013
# 19             Orissa  2013
# 20             Punjab  2013
# 21          Rajasthan  2013
# 22             Sikkim  2013
# 23          Tamilnadu  2013
# 24            Tripura  2013
# 25      Uttar Pradesh  2013
# 26        Uttaranchal  2013
# 27        West Bengal  2013
# 28      A & N Islands  2013
# 29         Chandigarh  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# ...

# %%
df.drop(["totals"], axis = 1, inplace = True)

# %%
df.sum()
# Out:
# STATE/UT                                             Andhra PradeshArunachal PradeshAssamBiharChhat...
# YEAR                                                                                             70455
# No. of Inmates benefitted by Elementary Education                                                37027
# No. of Inmates benefitted by Adult Education                                                     53720
# No. of Inmates benefitted by Higher Education                                                     8311
# No. of Inmates benefitted by Computer Course                                                      7356
# total_benefitted                                                                                106414
# dtype: object

# %%
df.columns
# Out:
# Index(['STATE/UT', 'YEAR', 'No. of Inmates benefitted by Elementary Education',
#        'No. of Inmates benefitted by Adult Education',
#        'No. of Inmates benefitted by Higher Education',
#        'No. of Inmates benefitted by Computer Course', 'total_benefitted'],
#       dtype='object')

# %%
new_row = {'STATE/UT':' ', 'YEAR':' ', 'No. of Inmates benefitted by Elementary Education':37027, 
            "No. of Inmates benefitted by Adult Education":53720, 
            'No. of Inmates benefitted by Higher Education':8311, 
            'No. of Inmates benefitted by Computer Course': 7356, 
            'total_benefitted':106414}

# %%
df.loc[-1] = new_row
df.reset_index(drop = True)
# Out:
#              STATE/UT  YEAR  \
# 0      Andhra Pradesh  2013
# 1   Arunachal Pradesh  2013
# 2               Assam  2013
# 3               Bihar  2013
# 4         Chhatisgarh  2013
# 5                 Goa  2013
# 6             Gujarat  2013
# 7             Haryana  2013
# 8    Himachal Pradesh  2013
# 9     Jammu & Kashmir  2013
# 10          Jharkhand  2013
# 11          Karnataka  2013
# 12             Kerala  2013
# 13     Madhya Pradesh  2013
# 14        Maharashtra  2013
# 15            Manipur  2013
# 16          Meghalaya  2013
# 17            Mizoram  2013
# 18           Nagaland  2013
# 19             Orissa  2013
# 20             Punjab  2013
# 21          Rajasthan  2013
# 22             Sikkim  2013
# 23          Tamilnadu  2013
# 24            Tripura  2013
# 25      Uttar Pradesh  2013
# 26        Uttaranchal  2013
# 27        West Bengal  2013
# 28      A & N Islands  2013
# 29         Chandigarh  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# ...

# %%
State_name= np.array(df["STATE/UT"])
benefitted = np.array(df["total_benefitted"])

# %%
barplot = plt.bar(State_name, benefitted)
plt.bar_label(barplot, labels=benefitted, label_type = "edge")
plt.figure(figsize= (52,6))
plt.show()

# %%
plt.pie([37027, 53720, 8311, 7356], labels= ['No. of Inmates benefitted by Elementary Education',
                                             'No. of Inmates benefitted by Adult Education',
                                             'No. of Inmates benefitted by Higher Education',
                                             'No. of Inmates benefitted by Computer Course'])
plt.plot()
# Out:
# []
