# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Rameshwar Agarwal\Desktop\python\assignment 5\HollywoodMovies.csv")
df
# Out:
#                                          Movie              LeadStudio  \
# 0                                 Spider-Man 3                    Sony
# 1                              Shrek the Third               Paramount
# 2                                 Transformers               Paramount
# 3     Pirates of the Caribbean: At World's End                  Disney
# 4    Harry Potter and the Order of the Phoenix             Warner Bros
# ..                                         ...                     ...
# 965                                The Canyons                     IFC
# 966                                   The Call                 TriStar
# 967                        The English Teacher  Cinedigm Entertainment
# 968                       John Dies at the End                Magnolia
# 969                                   Lovelace              Radius-TWC
#
#      RottenTomatoes  AudienceScore          Story      Genre  \
# ...

# %%
quest = df[df["Story"] == "Quest"]

print(quest["AudienceScore"][quest["AudienceScore"].idxmax()])
quest.loc[quest["AudienceScore"].idxmax()]
# Out:
# 87.0
# Movie               Harry Potter and the Deathly Hallows Part 1
# LeadStudio                                          Warner Bros
# RottenTomatoes                                             79.0
# AudienceScore                                              87.0
# Story                                                     Quest
# Genre                                                 Adventure
# TheatersOpenWeek                                         4125.0
# OpeningWeekend                                            125.0
# BOAvgOpenWeekend                                        30307.0
# DomesticGross                                             295.0
# ForeignGross                                              664.3
# WorldGross                                                959.3
# Budget                                                    125.0
# Profitability                                            767.44
# OpenProfit                                                100.0
# ...

# %%
df.groupby(["Genre"])[["Movie"]].count().idxmax()
# Out:
# Movie    Comedy
# dtype: object

# %%
sorted_df = df.sort_values(by = "Budget", ascending= False)
sorted_df[["LeadStudio", "Budget"]].head(10)
# Out:
#       LeadStudio  Budget
# 3         Disney   300.0
# 468       Disney   260.0
# 0           Sony   258.0
# 778  Warner Bros   250.0
# 241  Warner Bros   250.0
# 586       Disney   250.0
# 710  Buena Vista   250.0
# 239          Fox   237.0
# 99           MGM   230.0
# 770         Sony   230.0

# %%
Profitability = np.array(df["Profitability"])
RottenTomatoes = np.array(df["RottenTomatoes"])

# %%
import matplotlib.pyplot as plt
plt.scatter(RottenTomatoes, Profitability)
plt.show()

# %%
#import seaborn as sns
#sns.heatmap(df.corr(), annot = True)

# %%
di = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
      'last_name': ['Miller', 'Jacobson', "", 'Milner', 'Cooze'], 
      'age': [42, 52, 36, 24, 73], 
      'preTestScore': [4, 24, 31, "", ""],
      'postTestScore': ["25,000", "94,000", 57, 62, 70]}
raw_df = pd.DataFrame(di)
raw_df
# Out:
#   first_name last_name  age preTestScore postTestScore
# 0      Jason    Miller   42            4        25,000
# 1      Molly  Jacobson   52           24        94,000
# 2       Tina             36           31            57
# 3       Jake    Milner   24                         62
# 4        Amy     Cooze   73                         70

# %%
raw_df.to_csv(r"C:\Users\Rameshwar Agarwal\Desktop\python\example.csv")

# %%
raw_df1 = pd.read_csv(r"C:\Users\Rameshwar Agarwal\Desktop\python\example.csv")
print(raw_df1)
raw_df1.drop("Unnamed: 0", axis = 1, inplace = True)
raw_df1
# Out:
#    Unnamed: 0 first_name last_name  age  preTestScore postTestScore
# 0           0      Jason    Miller   42           4.0        25,000
# 1           1      Molly  Jacobson   52          24.0        94,000
# 2           2       Tina       NaN   36          31.0            57
# 3           3       Jake    Milner   24           NaN            62
# 4           4        Amy     Cooze   73           NaN            70
#   first_name last_name  age  preTestScore postTestScore
# 0      Jason    Miller   42           4.0        25,000
# 1      Molly  Jacobson   52          24.0        94,000
# 2       Tina       NaN   36          31.0            57
# 3       Jake    Milner   24           NaN            62
# 4        Amy     Cooze   73           NaN            70

# %%
R_raw_df1 = raw_df1.rename(columns = {'first_name':'First Name', 'last_name':'Last Name'})
R_raw_df1
# Out:
#   First Name Last Name  age  preTestScore postTestScore
# 0      Jason    Miller   42           4.0        25,000
# 1      Molly  Jacobson   52          24.0        94,000
# 2       Tina       NaN   36          31.0            57
# 3       Jake    Milner   24           NaN            62
# 4        Amy     Cooze   73           NaN            70

# %%
R_raw_df1.isnull()
# Out:
#    First Name  Last Name    age  preTestScore  postTestScore
# 0       False      False  False         False          False
# 1       False      False  False         False          False
# 2       False       True  False         False          False
# 3       False      False  False          True          False
# 4       False      False  False          True          False

# %%
skip_raw_df1 = pd.read_csv(r"C:\Users\Rameshwar Agarwal\Desktop\python\example.csv", skiprows = range(1,4))
print(skip_raw_df1.drop("Unnamed: 0", axis=1))
# Out:
#   first_name last_name  age  preTestScore  postTestScore
# 0       Jake    Milner   24           NaN             62
# 1        Amy     Cooze   73           NaN             70

# %%
lst = ['Amit', 'Bob', 'Kate', 'A', 'b', np.nan, 'Car', 'dog', 'cat']
series = pd.Series(lst)
df_series = pd.DataFrame(series)
print(df_series[0].str.upper())
print(df_series[0].str.lower())
print(len(df_series[0]))
# Out:
# 0    AMIT
# 1     BOB
# 2    KATE
# 3       A
# 4       B
# 5     NaN
# 6     CAR
# 7     DOG
# 8     CAT
# Name: 0, dtype: object
# 0    amit
# 1     bob
# 2    kate
# 3       a
# 4       b
# 5     NaN
# 6     car
# 7     dog
# 8     cat
# Name: 0, dtype: object
# 9

# %%
count= 0
for i in series:
    if series.empty() == True:
        print(i, 0)
    else:
        for j in range(0, len(i)): 
            count= count+1
        print(i, count)
        count = 0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 count= 0
#       2 for i in series:
# ----> 3     if series.empty() == True:
#       4         print(i, 0)
#       5     else:
#
# TypeError: 'bool' object is not callable

# %%
name = [' Atul', 'John ',' jack ', 'Sam']
series2 = pd.Series(name)
series_df = pd.DataFrame(series2)
print(series_df[0].str.strip(" "))
print(series_df[0].str.lstrip(" "))
print(series_df[0].str.rstrip(" "))
# Out:
# 0    Atul
# 1    John
# 2    jack
# 3     Sam
# Name: 0, dtype: object
# 0     Atul
# 1    John
# 2    jack
# 3      Sam
# Name: 0, dtype: object
# 0     Atul
# 1     John
# 2     jack
# 3      Sam
# Name: 0, dtype: object

# %%
lst = ['A', 'B', 'C', 'AabX', 'BacX','', np.nan, 'CABA', 'dog', 'cat']
series = pd.Series(lst)
series = series.str.replace('X', 'XX-XX')
series = series.str.replace('dog', 'XX-XX')
series
# Out:
# 0           A
# 1           B
# 2           C
# 3    AabXX-XX
# 4    BacXX-XX
# 5
# 6         NaN
# 7        CABA
# 8       XX-XX
# 9         cat
# dtype: object

# %%
lst = ['12', '-$10', '$10,000']
series = pd.Series(lst)
for i in range(0, series.size):
    for j in range(0, len(series[i])):
        if series[i][j] != '$':
            print(series[i][j])
# Out:
# 1
# 2
# -
# 1
# 0
# 1
# 0
# ,
# 0
# 0
# 0

# %%
lst = ['1', '2', '1a', '2b', '2003c']
series = pd.Series(lst)
for i in series:
    if i.isalnum() == True:
        print("true")
# Out:
# true
# true
# true
# true
# true

# %%
lst = ['1', '2', '1a', '2b', 'America', 'VietnAm','vietnam', '2003c']
series = pd.Series(lst)
for i in range(0, series.size):
    for j in range(0, len(series[i])):
        if series[i][j] == 'A':
            print(series[i])
            break
# Out:
# America
# VietnAm

# %%
lst = ['a', 'a|b', np.nan, 'a|c']
series = pd.Series(lst)
df = pd.DataFrame(index = series, columns = ['a', 'b', 'c'])
print(df)

# %%
dict = {'key': ['One', 'Two'], 'ltable': [1, 2]}
dict1 = {'key': ['One', 'Two'], 'rtable': [4, 5]}
left = pd.DataFrame(dict)
print(left)
right = pd.DataFrame(dict1)
print(right)
pd.merge(left, right, on = 'key')
# Out:
#    key  ltable
# 0  One       1
# 1  Two       2
#    key  rtable
# 0  One       4
# 1  Two       5
#    key  ltable  rtable
# 0  One       1       4
# 1  Two       2       5
